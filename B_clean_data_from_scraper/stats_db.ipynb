# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../Nexus.db")
df = pd.read_sql_query("SELECT * FROM notifications", conn)
conn.close()

# %%
df.head()
# Out:
#    id                 company_name              date market issuer_id  \
# 0   1  Ayfie International AS.json  04.09.2025 09:05   MERK       AIX
# 1   2  Ayfie International AS.json  28.08.2025 10:22   MERK       AIX
# 2   3  Ayfie International AS.json  09.05.2025 18:17   MERK       AIX
# 3   4  Ayfie International AS.json  15.01.2025 15:02   MERK       AIX
# 4   5  Ayfie International AS.json  30.12.2024 16:12   MERK       AIX
#
#              link                                            message  \
# 0  message_654625  Godthåb Holding AS has today bought 105.000  s...
# 1  message_654077  HAAS AS has today bought 150.000 shares in Ayf...
# 2  message_645945  Reference is made to the stock exchange announ...
# 3  message_636562  On 30 December 2024/14th January 2025, a demer...
# 4  message_635776  HAAS AS has today bought 33.343 shares in Ayfi...
#
#                                             pdf_text
# 0
# 1
# 2  KRT-1500 Skjema for melding om transaksjoner u...
# 3
# 4

# %%
print(len(df))
print("\n")
print(df["company_name"].value_counts())
print("\n")
print(df["market"].value_counts())
print("\n")
print(df["issuer_id"].value_counts())
# Out:
# 17711
#
#
# company_name
# Veidekke ASA.json                601
# AMSC ASA.json                    592
# Drangedal Sparebank.json         592
# Rindal Sparebank.json            592
# Tinn Sparebank.json              592
#                                 ...
# Aider Konsern AS.json              1
# Sparebank 68 grader nord.json      1
# Flekkefjord Sparebank.json         1
# DNB Boligkreditt AS.json           1
# Nidaros Sparebank.json             1
# Name: count, Length: 314, dtype: int64
#
#
# market
# XOSL                12724
# MERK                 2294
# XOSL, XOAM           1619
# XOAX                  798
# XOAM, MERK            171
# XOAM                   64
# XOSL, XOAX             15
# XOSL, MERK             15
# XOAX, MERK              4
# XOSL, XOAX, XOAM        3
# XOAX, XOAM              3
# XOSL, XOAX, MERK        1
# Name: count, dtype: int64
#
#
# issuer_id
# VEI      625
# ORK      472
# SBO      278
# AFG      271
# EQNR     258
#         ...
# SB68       1
# ...
